# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()  # Opens a file picker
df = pd.read_csv(next(iter(uploaded)))  # Reads the uploaded CSv
# Out:
#      <input type="file" id="files-6a19f60e-3277-40f5-ac93-409372c5e7f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a19f60e-3277-40f5-ac93-409372c5e7f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head(
        )
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1111
# 1     192
# Name: count, dtype: int64

# %%
df['IPSpanel']=df['ScreenResolution'].apply(lambda x:1 if 'IPS Panel' in x else 0)
df['IPSpanel'].value_counts()
# Out:
# IPSpanel
# 0    938
# 1    365
# Name: count, dtype: int64

# %%
sns.barplot(x='IPSpanel',y='Price',data=df)
# Out:
# <Axes: xlabel='IPSpanel', ylabel='Price'>

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Touchscreen         0
# IPSpanel            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=['Unnamed: 0'],axis=1)
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832            0
# ...

# %%
df['Ram']=df['Ram'].str.replace('GB','')
df['Weight']=df['Weight'].str.replace('kg','')
df.head(5)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832            0
# ...

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price             1303 non-null   float64
#  12  Touchscreen       1303 non-null   int64
#  13  IPSpanel          1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(3), object(7)
# memory usage: 132.5+ KB

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res']=new[0]
df['Y_res']=new[1]
df.head(5)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# ...

# %%
df['X_res']=df['X_res'].str.extract(r'(\d{4})')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# ...

# %%
df['X_res']=df['X_res'].astype(int)
df['Y_res']=df['Y_res'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price             1303 non-null   float64
#  12  Touchscreen       1303 non-null   int64
#  13  IPSpanel          1303 non-null   int64
#  14  X_res             1303 non-null   int64
#  15  Y_res             1303 non-null   int64
# ...

# %%
df['ppi']=((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches']
df['ppi']=df['ppi'].astype('float')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# ...

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                         Cpu  Ram  \
# 0           0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1           1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2           2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3           3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4           4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPSpanel  X_res  Y_res         ppi
# ...

# %%
df.drop(columns=['X_res','Y_res','Inches'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName                         Cpu  Ram  \
# 0           0   Apple  Ultrabook        Intel Core i5 2.3GHz    8
# 1           1   Apple  Ultrabook        Intel Core i5 1.8GHz    8
# 2           2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3           3   Apple  Ultrabook        Intel Core i7 2.7GHz   16
# 4           4   Apple  Ultrabook        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPSpanel         ppi
# 0   71378.6832            0         1  226.983005
# 1   47895.5232            0         0  127.677940
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPSpanel         ppi
# 0         1  226.983005
# 1         0  127.677940
# ...

# %%
df['cpu_info']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df['cpu_info']
# Out:
# 0            Intel Core i5
# 1            Intel Core i5
# 2            Intel Core i5
# 3            Intel Core i7
# 4            Intel Core i5
#                ...
# 1298         Intel Core i7
# 1299         Intel Core i7
# 1300    Intel Celeron Dual
# 1301         Intel Core i7
# 1302    Intel Celeron Dual
# Name: cpu_info, Length: 1303, dtype: object

# %%
def fetch(text):
  if text == 'Intel Core i5' or text=='Intel Core i7' or text=='Intel Core i3':
    return text
  else:
    if text.split()[0]=='Intel':
      return 'Other Intel Processor'
    else:
      return 'AMD'

# %%
df['CPU_brand']=df['cpu_info'].apply(fetch)
df['CPU_brand']
# Out:
# 0               Intel Core i5
# 1               Intel Core i5
# 2               Intel Core i5
# 3               Intel Core i7
# 4               Intel Core i5
#                 ...
# 1298            Intel Core i7
# 1299            Intel Core i7
# 1300    Other Intel Processor
# 1301            Intel Core i7
# 1302    Other Intel Processor
# Name: CPU_brand, Length: 1303, dtype: object

# %%
df.drop(columns=['Cpu','cpu_info'],inplace=True)

# %%
df.head(5)
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPSpanel         ppi  \
# 0  macOS    1.37   71378.6832            0         1  226.983005
# 1  macOS    1.34   47895.5232            0         0  127.677940
# 2  No OS    1.86   30636.0000            0         0  141.211998
# 3  macOS    1.83  135195.3360            0         1  220.534624
# 4  macOS    1.37   96095.8080            0         1  226.983005
#
#        CPU_brand
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# 3  Intel Core i7
# 4  Intel Core i5

# %%
sns.barplot(x=df['CPU_brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.boxplot(x='Ram',y='Price',data=df)
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
# Step 1: Clean up Memory column
df['Memory'] = df['Memory'].fillna('').astype(str)
df['Memory'] = df['Memory'].str.replace(r'\.0', '', regex=True)
df['Memory'] = df['Memory'].str.replace('GB', '')
df['Memory'] = df['Memory'].str.replace('TB', '000')

# Step 2: Split into two parts
new = df['Memory'].str.split('+', n=1, expand=True)
df['first'] = new[0].str.strip()
df['second'] = new[1].fillna('0')

# Step 3: Encode storage types (Layer 1)
df['Layer1HDD'] = df['first'].str.contains('HDD').astype(int)
df['Layer1SSD'] = df['first'].str.contains('SSD').astype(int)
df['Layer1Hybrid'] = df['first'].str.contains('Hybrid').astype(int)
df['Layer1Flash_Storage'] = df['first'].str.contains('Flash Storage').astype(int)

# Step 4: Encode storage types (Layer 2)
df['Layer2HDD'] = df['second'].str.contains('HDD').astype(int)
df['Layer2SSD'] = df['second'].str.contains('SSD').astype(int)
df['Layer2Hybrid'] = df['second'].str.contains('Hybrid').astype(int)
df['Layer2Flash_Storage'] = df['second'].str.contains('Flash Storage').astype(int)

# Step 5: Keep only digits, replace empty with 0
df['first'] = df['first'].str.replace(r'\D', '', regex=True).replace('', '0').astype(int)
df['second'] = df['second'].str.replace(r'\D', '', regex=True).replace('', '0').astype(int)

# Step 6: Aggregate into final columns
df['HDD'] = df['first']*df['Layer1HDD'] + df['second']*df['Layer2HDD']
df['SSD'] = df['first']*df['Layer1SSD'] + df['second']*df['Layer2SSD']
df['Hybrid'] = df['first']*df['Layer1Hybrid'] + df['second']*df['Layer2Hybrid']
df['Flash_Storage'] = df['first']*df['Layer1Flash_Storage'] + df['second']*df['Layer2Flash_Storage']

# Step 7: Drop helper columns
df.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid',
                 'Layer1Flash_Storage','Layer2HDD','Layer2SSD','Layer2Hybrid',
                 'Layer2Flash_Storage'], inplace=True)

# %%
df.head(5)
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPSpanel         ppi  \
# 0  macOS    1.37   71378.6832            0         1  226.983005
# 1  macOS    1.34   47895.5232            0         0  127.677940
# 2  No OS    1.86   30636.0000            0         0  141.211998
# 3  macOS    1.83  135195.3360            0         1  220.534624
# 4  macOS    1.37   96095.8080            0         1  226.983005
#
#        CPU_brand  HDD  SSD  Hybrid  Flash_Storage
# 0  Intel Core i5    0  128       0              0
# ...

# %%
df.drop(columns=['Memory','Flash_Storage','Hybrid'],inplace=True)

# %%
df.head(5)
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPSpanel         ppi      CPU_brand  HDD  SSD
# 0   71378.6832            0         1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0         0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0         0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0         1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0         1  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu_brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram                      Gpu       OpSys  \
# 841     Dell              Gaming   32  Nvidia GeForce GTX 1070  Windows 10
# 1285  Lenovo  2 in 1 Convertible   16    Intel HD Graphics 520  Windows 10
# 179       HP  2 in 1 Convertible    8   Intel UHD Graphics 620  Windows 10
# 444       HP              Gaming    8  Nvidia GeForce GTX 1050  Windows 10
# 310   Lenovo            Notebook    8    Intel HD Graphics 620  Windows 10
#
#       Weight        Price  Touchscreen  IPSpanel         ppi      CPU_brand  \
# 841     4.42  163723.5792            0         1  127.335675  Intel Core i7
# 1285    1.30   79866.7200            1         1  276.053530  Intel Core i7
# 179     1.29   79866.7200            1         1  331.264236  Intel Core i5
# 444     2.20   58554.7200            0         1  141.211998  Intel Core i7
# 310     1.10   53226.7200            0         1  165.632118  Intel Core i5
#
#        HDD  SSD Gpu_brand
# 841   1000  512    Nvidia
# ...

# %%
df=df[df['Gpu_brand']!='ARM']

# %%
sns.barplot(x=df['Gpu_brand'],y=df['Price'])
plt.show()

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def check(text):
  if text=='Windows 10' or text=='Windows 10' or text=='Windows 10 S':
    return 'Windows'
  elif text=='Mac OS X' or text=='macOS':
    return 'Mac'
  else:
    return 'Other OS'

# %%
df['os']=df['OpSys'].apply(check)
# Out:
# /tmp/ipython-input-1694898302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['os']=df['OpSys'].apply(check)

# %%
df['os']
# Out:
# 0            Mac
# 1            Mac
# 2       Other OS
# 3            Mac
# 4            Mac
#           ...
# 1298     Windows
# 1299     Windows
# 1300     Windows
# 1301     Windows
# 1302     Windows
# Name: os, Length: 1302, dtype: object

# %%
df.head(5)
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPSpanel         ppi      CPU_brand  HDD  SSD  \
# 0   71378.6832            0         1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0         0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0         0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0         1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0         1  226.983005  Intel Core i5    0  256
#
#   Gpu_brand        os
# 0     Intel       Mac
# 1     Intel       Mac
# ...

# %%
df.drop(columns=['Gpu','OpSys'],inplace=True)
# Out:
# /tmp/ipython-input-1121584336.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Gpu','OpSys'],inplace=True)

# %%
df.head(5)
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPSpanel  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0         1
# 1   Apple  Ultrabook    8    1.34   47895.5232            0         0
# 2      HP   Notebook    8    1.86   30636.0000            0         0
# 3   Apple  Ultrabook   16    1.83  135195.3360            0         1
# 4   Apple  Ultrabook    8    1.37   96095.8080            0         1
#
#           ppi      CPU_brand  HDD  SSD Gpu_brand        os
# 0  226.983005  Intel Core i5    0  128     Intel       Mac
# 1  127.677940  Intel Core i5    0    0     Intel       Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Other OS
# 3  220.534624  Intel Core i7    0  512       AMD       Mac
# 4  226.983005  Intel Core i5    0  256     Intel       Mac

# %%
X=df.drop('Price',axis=1)
y=np.log(df['Price'])
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPSpanel  \
# 0      Apple           Ultrabook    8    1.37            0         1
# 1      Apple           Ultrabook    8    1.34            0         0
# 2         HP            Notebook    8    1.86            0         0
# 3      Apple           Ultrabook   16    1.83            0         1
# 4      Apple           Ultrabook    8    1.37            0         1
# ...      ...                 ...  ...     ...          ...       ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1         1
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1         1
# 1300  Lenovo            Notebook    2    1.50            0         0
# 1301      HP            Notebook    6    2.19            0         0
# 1302    Asus            Notebook    4    2.20            0         0
#
#              ppi              CPU_brand   HDD  SSD Gpu_brand        os
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from xgboost import XGBRegressor
from sklearn.preprocessing import OneHotEncoder

# %%
step1 = ColumnTransformer(
    transformers=[
        ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0,1,7,10,11])
    ],
    remainder='passthrough'
)
step2 = LinearRegression()
model = Pipeline([
    ('step1', step1),
    ('step2', step2)
])
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   [0, 1, 7, 10, 11])])),
#                 ('step2', LinearRegression())])

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8034545425683494
